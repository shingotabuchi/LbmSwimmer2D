# %%
import pandas as pd
import numpy as np
import os
import matplotlib.patches as patches
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('figure',  figsize=(8, 8))
# mpl.rc('text', usetex=True)
# mpl.rc('font',**{'family':'sans-serif','sans-serif':['Comic Sans MS']})
# mpl.rc('mathtext', fontset='stixsans')
# mpl.rc('text.latex', preamble=r'\usepackage{cmbright}')
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.rm'] = 'Arial'
mpl.rcParams['mathtext.it'] = 'Arial'
mpl.rcParams['mathtext.bf'] = 'Arial'
hfont = {'fontname':'Arial'}

# %%
kanjiListString = "一丁七万丈三上下不与丐丑世丘丙丞両並中串丸丹主丼乃久乎乏乖乗乙九乞乱乳乾亀了予争事二云互五井些亜亡交亥亨享京亭人什仁仄仇今介仏仔仕他仗付仙仞代令以仮仰仲件任仿企伊伍伎伏伐休会伝伯伴伶伸伺似伽佃佇位低住佐佑体何余佚作佝佞佩佯佳併佶佻使侈例侍侏侘供依侠価侭侮侯侵侶便係促俄俊俎俗俘俚保信修俯俳俵俸倅倉個倍倏倒倔倖候倚借倣値倥倦倨倪倫倭倶倹偃偉偏停健偬側偵偶偸偽傀傅傍傑傘備催傭傲債傷傾僂僅働像僑僕僚僥僧僭僻儀億儒儕儘償儡優儷儺儼允元兄充兆先光克兌免兎児党兜兢入全八公六共兵其具典兼内円冊再冑冒冗写冠冤冥冦冪冬冶冷冽凄准凋凌凍凛凝几凡処凧凪凰凱凶凸凹出函刀刃分切刈刊刎刑列初判別利刮到制刷券刹刺刻剃則削剌前剔剖剛剣剤剥剪副剰割剴創剽剿劇劈力功加劣助努劫励労効劾勁勃勅勇勉勒動勘務勝募勢勤勧勲勾勿匂包匈匍匐匕化北匠匡匪匱匹区医匿十千午卉半卍卑卒卓協南単博卜占卦卯印危即却卵卸卿厄厘厚原厨厩厭厳去参叉及友双反収取受叙叛叡叢口古句叩只叫召可台叱史右号司吃各合吉吊同名后吏吐向君吝吟否含吶吸吹吻吽吾呂呆呈呉告呑周呪呱味呵呻呼命咀咄咆和咤咫咬咳咽哀品哄哉員哨哭哮哲哺唄唆唇唐唖唯唱唾商問啓啖啞啾喀喃善喉喊喘喙喚喜喝喧喨喩喪喫喬喰営嗅嗇嗚嗜嗟嗣嗤嗽嗾嘆嘉嘔嘘嘩嘯嘱嘲嘴噌器噬噯噴噺嚆嚇嚠嚢嚥嚮嚼囂囃囊囚四回因団困囲図囹固国圃圄圏園土圧在圭地址坂均坊坏坐坑坤坦坪垂型垢垣埃埋城埒域埠埴執培基堀堂堅堆堕堡堤堪堰報場堵塀塁塊塑塔塗塘塚塞塩填塵塹塾境墅墓増墜墟墨墳墾壁壇壊壌壕壟士壮声売壷壺変夏夕外多夜夢夥大天太夫夭央失夷夾奄奇奈奉奏契奔套奠奢奥奨奪奮女奴奸好如妃妄妊妓妖妙妣妥妨妬妹妻妾姉始姑姓委姜姥姦姫姻姿威娘娜娟娠娥娩娯娼婀婆婉婚婢婦婪婿媒媚媛媼媽嫁嫉嫋嫌嫡嫣嫦嫩嬉嬋嬌嬖嬢嬪嬰子孔字存孜孝孟季孤学孩孫孵孺�
��蹕蹙蹠蹣蹤蹲蹴蹶躁躅躇躊躍躑躙身躬躯躾軀車軋軌軍軒軟転軸軼軽較載輊輓輔輜輝輦輩輪輸輻輿轄轍轟轡轢辛辜辞辟辣辨辰辱農辺辻迂迅迎近返迦迫迭述迷迸迹追退送逃逅逆逍透逐逑逓途逗這通逝逞速造逡逢連逮週進逸逼遁遂遅遇遊運遍過遏遐道達違遜遠遡遣遥適遭遮遵遷選遺遼遽避邀邁邂邃還邏邑那邦邪邯邸郁郊郎郡部郭郵郷都鄙鄲酉酊酋酌配酎酒酔酢酩酪酬酵酷酸醂醇醍醐醒醜醤醵醸醺采釈釉里重野量釐金釘釜針釣釦鈍鈞鈴鈷鈿鉄鉈鉛鉞鉢鉤鉦鉱鉾銀銃銅銑銘銚銜銭鋏鋒鋤鋩鋭鋲鋳鋸鋼錆錐錠錦錨錫錬錯録鍋鍍鍔鍛鍬鍮鍵鍼鍾鎌鎖鎧鎮鏃鏑鏖鏡鏤鐐鐘鐸鑑鑞鑠鑰鑼鑽鑿長門閃閉開閏閑間関閣閤閥閨閲閾闇闊闕闖闘闡闢阜阪防阻阿陀附陋降限陛院陣除陥陪陬陰陳陵陶陸険陽隅隆隈隊階随隔隘隙際障隠隣隲隷隻雀雁雄雅集雇雌雑雛離難雨雪雲零雷雹電需霆震霊霑霜霞霧霰露霹靂靄青靖静非靡面革靭靱靴鞄鞅鞋鞍鞘鞜鞠鞭韓韜音韻響頁頂頃項順須預頑頒頓頗領頚頤頬頭頸頻頼頽顆題額顎顔顕願顛類顧顫顰顴風颪颯颶飄飛食飢飩飭飯飲飴飼飽飾餅餉養餌餐餓餞餡館饅饉饋饌饒饗首馗馘香馥馨馬馳馴駁駄駅駆駐駑駒駕駘駛駢駭駸駿騁騎騒験騙騰驀驍驕驚驟驥骨骸髀髄高髦髪髭髯髷髻鬘鬚鬢鬧鬨鬱鬼魁魂魄魅魍魎魔魚魯鮎鮑鮒鮨鮫鮭鮮鯉鯖鯛鯨鯰鯵鰈鰐鰭鰯鰹鰺鰻鱈鱗鳥鳩鳳鳴鳶鴃鴟鴨鴬鴻鵄鵜鵞鵠鵬鶉鶏鶫鶲鶴鶸鷲鷹鷺鹵鹸鹹鹿麈麓麗麝麦麩麵麹麺麻麼麾麿黄黍黎黐黒黙黛黜黯黴鼈鼎鼓鼠鼻鼾齟齢齣齦齬齲龍龜﨟";
Corpus_count = pd.read_csv('Corpus_count.csv',header = None)
Answer_key_forWebsiteSheet1 = pd.read_csv('Answer_key_forWebsiteSheet1.csv')
RAT_20230511RAT_Q = pd.read_csv('RAT_20230511RAT_Q.csv')

print(Answer_key_forWebsiteSheet1)
# Out:
#     Unnamed: 0 Q1 NoFix_1 Fix_1 Q2 No_Fix2 Fix_2 Q3 No_Fix3 Fix_3 Ans  \
# 0            1  兵       察     法  艦       場     艇  軍       義     医   隊
# 1            2  確       合     証  受       器     検  迷       塩     宮   信
# 2           11  余       学     暇  漂       板     流  明       音     日   白
# 3           12  工       済     具  表       界     彰  仮       国     病   面
# 4           21  引       芸     用  辞       伸     令  中       董     華   退
# 5           22  避       約     妊  非       感     常  女       遇     神   難
# 6           31  道       汁     草  快       愛     速  歓       釈     迎   楽
# 7           32  契       存     約  好       願     感  待       雨     遇   機
# 8           41  警       法     察  広       艇     場  忠       医     義   告
# 9           42  安       満     易  勘       分     当  協       料     和   定
# 10          51  充       集     満  節       位     分  送       処     料   電
# 11          52  収       判     益  装       体     置  花       筋     火   束
# ...

# %%
kanjiToIndex = dict()
for i in range(len(kanjiListString)):
    kanjiToIndex[kanjiListString[i]] = i

# %%
# average or minimum or maximum
# normalize by local of global maximum
ansdists = dict()
fixdists = dict()
for index, row in Answer_key_forWebsiteSheet1.iterrows():
    kanji1 = row['Q1']
    kanji2 = row['Q2']
    kanji3 = row['Q3']
    kanjiIndex = [kanjiToIndex[kanji1],kanjiToIndex[kanji2],kanjiToIndex[kanji3]]
    fixkanji1 = row['Fix_1']
    fixkanji2 = row['Fix_2']
    fixkanji3 = row['Fix_3']
    fixkanjiIndex = [kanjiToIndex[fixkanji1],kanjiToIndex[fixkanji2],kanjiToIndex[fixkanji3]]
    anskanjiIndex = kanjiToIndex[row['Ans']]
    ansdist = row['Ans']
    ansdist = 0.0
    fixdist = 0.0
    for i in range(3):
        ansdist += 1.0/Corpus_count[anskanjiIndex][kanjiIndex[i]]
        fixdist += 1.0/Corpus_count[fixkanjiIndex[i]][kanjiIndex[i]]
    ansdists[Answer_key_forWebsiteSheet1.iloc[index][0]] = ansdist
    fixdists[Answer_key_forWebsiteSheet1.iloc[index][0]] = fixdist

# %%
fixdists
# Out:
# {1: 0.0018946405952848743,
#  2: 0.0016695226572479027,
#  11: 0.001178668906704884,
#  12: 0.003248188207292073,
#  21: 0.0008076554306063454,
#  22: 0.00030812491466244415,
#  31: 0.002635118020660223,
#  32: 0.00031900035565446926,
#  41: 0.0013493287948472582,
#  42: 0.006306207950209738,
#  51: 0.005245293727577857,
#  52: 0.00014444932907262863,
#  61: 0.0028984365262366297,
#  62: 0.0020574419398813456,
#  71: 0.00028648981327288205,
#  72: 0.004390320721590072}

# %%
rat_q_df = RAT_20230511RAT_Q
participantSet = set(rat_q_df['Participant #'])
for part in participantSet:
    subdata = rat_q_df[rat_q_df['Participant #'] == part]
    allFalse = True
    for index, row in subdata.iterrows():
        if row['AnswerKey']:
            allFalse = False
            break
    if allFalse:
        rat_q_df = rat_q_df[rat_q_df['Participant #'] != part]

# %%
fixedrat = RAT_20230511RAT_Q[RAT_20230511RAT_Q['Fix or NoFix'] == 'Fix']
nofixrat = RAT_20230511RAT_Q[RAT_20230511RAT_Q['Fix or NoFix'] == 'NoFix']
fixedrat_q_df_true = fixedrat[fixedrat['AnswerKey']]
nofixrat_q_df_true = nofixrat[nofixrat['AnswerKey']]

# %%
fixedrat_q_df_true_aha = fixedrat_q_df_true[fixedrat_q_df_true['Aha'] == 'yes']
fixedrat_q_df_true_noaha = fixedrat_q_df_true[fixedrat_q_df_true['Aha'] == 'no']
nofixrat_q_df_true_aha = nofixrat_q_df_true[nofixrat_q_df_true['Aha'] == 'yes']
nofixrat_q_df_true_noaha = nofixrat_q_df_true[nofixrat_q_df_true['Aha'] == 'no']

# %%
fixedMeanAnsTimeAha = dict()
fixedMeanAnsTimeNoAha = dict()
nofixMeanAnsTimeAha = dict()
nofixMeanAnsTimeNoAha = dict()
for index, row in Answer_key_forWebsiteSheet1.iterrows():
    qno = Answer_key_forWebsiteSheet1.iloc[index][0]
    fixedMeanAnsTimeAha[qno] = fixedrat_q_df_true_aha[fixedrat_q_df_true_aha['Q_No'] == qno]['Solving_Time'].mean()
    fixedMeanAnsTimeNoAha[qno] = fixedrat_q_df_true_noaha[fixedrat_q_df_true_noaha['Q_No'] == qno]['Solving_Time'].mean()
    nofixMeanAnsTimeAha[qno] = nofixrat_q_df_true_aha[nofixrat_q_df_true_aha['Q_No'] == qno]['Solving_Time'].mean()
    nofixMeanAnsTimeNoAha[qno] = nofixrat_q_df_true_noaha[nofixrat_q_df_true_noaha['Q_No'] == qno]['Solving_Time'].mean()

# %%
nofixMeanAnsTimeAha
# Out:
# {1: 7.3148928571428575,
#  2: 13.555346153846152,
#  11: 10.904874999999999,
#  12: 13.755260869565216,
#  21: 13.682155555555555,
#  22: 15.014078947368423,
#  31: 8.259085714285714,
#  32: 13.459571428571428,
#  41: 9.912535714285713,
#  42: 10.817146341463415,
#  51: 14.8811,
#  52: 16.622388888888892,
#  61: 14.157692307692308,
#  62: 15.32796153846154,
#  71: 13.621333333333334,
#  72: 15.920928571428572}

# %%
fixedMeanAnsTimeAha
# Out:
# {1: 12.543404761904762,
#  2: 16.494857142857143,
#  11: 13.010773584905658,
#  12: 18.963315789473686,
#  21: 16.80864285714286,
#  22: 16.6946875,
#  31: 15.66688,
#  32: 13.39690625,
#  41: 19.088857142857144,
#  42: 14.67296,
#  51: 19.187190476190473,
#  52: 17.639,
#  61: 23.869307692307686,
#  62: 19.07283333333333,
#  71: 30.670875,
#  72: 24.512833333333333}

# %%
# omega0 = 0.1
# gamma = 0.2
# initVel = 0.1
# initPos = 0.1

# %%
def occilation_pos(t,omega0,gamma,initVel,initPos):
    if omega0 > gamma:
        omega = np.sqrt(omega0**2 - gamma**2)
        return np.exp(-gamma*t)*(initPos * np.cos(omega*t) + ((gamma*initPos + initVel)/omega)*np.sin(omega*t))
    if omega0 == gamma:
        return ((initVel + gamma * initPos)*t + initPos) * np.exp(-gamma*t)
    if omega0 < gamma:
        gammaPlus = gamma + np.sqrt(gamma**2-omega0**2)
        gammaMinus = gamma - np.sqrt(gamma**2-omega0**2)
        C1 = (-initVel - gammaMinus*initPos)/(gammaPlus-gammaMinus)
        C2 = (initVel + gammaPlus*initPos)/(gammaPlus-gammaMinus)
        return C1*np.exp(-gammaPlus*t) + C2*np.exp(-gammaMinus*t)

# %%
def occilation_vel(t,omega0,gamma,initVel,initPos):
    if omega0 > gamma:
        omega = np.sqrt(omega0**2 - gamma**2)
        return -gamma*occilation_pos(t,omega0,gamma,initVel,initPos) + np.exp(-gamma*t)*(-initPos * omega*np.sin(omega*t) + (gamma*initPos + initVel)*np.cos(omega*t))
    if omega0 == gamma:
        return -gamma*occilation_pos(t,omega0,gamma,initVel,initPos) + (initVel + gamma * initPos) * np.exp(-gamma*t)
    if omega0 < gamma:
        gammaPlus = gamma + np.sqrt(gamma**2-omega0**2)
        gammaMinus = gamma - np.sqrt(gamma**2-omega0**2)
        C1 = (-initVel - gammaMinus*initPos)/(gammaPlus-gammaMinus)
        C2 = (initVel + gammaPlus*initPos)/(gammaPlus-gammaMinus)
        return -gammaPlus*C1*np.exp(-gammaPlus*t) -gammaMinus*C2*np.exp(-gammaMinus*t)

# %%
def convergetime(dt,omega0,gamma,initVel,initPos):
    t = 0
    while True:
        pos = occilation_pos(t,omega0,gamma,initVel,initPos)
        vel = occilation_vel(t,omega0,gamma,initVel,initPos)
        if np.abs(pos) <= 0.1 and np.abs(vel) <= 0.1:
            return t
        t += dt

# %%
t = np.linspace(0,10,1000)
plt.plot(t,occilation_pos(t,10,1,-100,1))

# %%
from matplotlib import cm
omega0 = 1.0
gamma = np.linspace(0.25,10,20)
initVel = -np.linspace(0,100,20)
ct = np.zeros((len(gamma),len(initVel)))
for i in range(len(gamma)):
    for j in range(len(initVel)):
        ct[i][j] = convergetime(0.02,omega0,gamma[i],initVel[j],5)

ctgammaAveraged = np.zeros(len(initVel))
ctinitVelAveraged = np.zeros(len(gamma))
for i in range(len(gamma)):
    for j in range(len(initVel)):
        ctgammaAveraged[j] += ct[i][j]
        ctinitVelAveraged[i] += ct[i][j]

plt.plot(initVel,ctgammaAveraged)
plt.show()
plt.plot(gamma,ctinitVelAveraged)
plt.show()

print(gamma[0],initVel[0])
plt.ylabel("damp",fontsize = 30,**hfont)
plt.xlabel("initial velocity",fontsize = 30,**hfont)
plt.xticks([0,-50,-100],fontname = "Arial",fontsize = 20)
plt.yticks([5,10],fontname = "Arial",fontsize = 20)
plt.pcolormesh(initVel,gamma,ct)
plt.contour(initVel, gamma, ct,10,colors = 'white')
plt.show()
plt.ylabel("damp")
plt.xlabel("initial velocity")
plt.pcolormesh(gamma,initVel,ct)
plt.show()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
initVel, gamma = np.meshgrid(initVel, gamma)
X, Y, Z = initVel, gamma, ct
# Plot the 3D surface
ax.plot_surface(X, Y, Z, edgecolor='royalblue', lw=0.5, rstride=8, cstride=8,
                alpha=0.3)

# # Plot projections of the contours for each dimension.  By choosing offsets
# # that match the appropriate axes limits, the projected contours will sit on
# # the 'walls' of the graph.
# # ax.contour(X, Y, Z, zdir='z', offset=-1, cmap='coolwarm')
# # ax.contour(X, Y, Z, zdir='x', offset=-1, cmap='coolwarm')
# ax.contour(X, Y, Z, zdir='y', offset=5, cmap='coolwarm')

# ax.set(xlim=(-30, 0), ylim=(0, 5),
#        xlabel='init vel', ylabel='damp')
# # ax.view_init(azim=0)
# plt.show()
# ax.pcolormesh(initVel, gamma, ct)

# ax.bar3d(initVel,gamma,1,1,1,ct)
# ax.plot_surface(initVel,gamma,ct,cmap=cm.coolwarm)
# plt.ylabel("damp")
# plt.xlabel("init vel")
# ax.view_init(azim=170)
# plt.show()
# Out:
# 0.25 -0.0
# C:\Users\tonoy\AppData\Local\Temp/ipykernel_18448/1361117170.py:27: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(initVel,gamma,ct)
# C:\Users\tonoy\AppData\Local\Temp/ipykernel_18448/1361117170.py:32: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(gamma,initVel,ct)
